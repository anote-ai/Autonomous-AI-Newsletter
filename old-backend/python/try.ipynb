# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
import json
from bs4 import BeautifulSoup
import requests
from dotenv import load_dotenv
import os
import openai
import os
from dotenv import load_dotenv

# %%
session = requests.Session()
headers = {
        'User-Agent' : 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:46.0) Gecko/20100101 Firefox/46.0',
        'Content-Type': 'application/x-www-form-urlencoded',
        'Connection' : 'Keep-Alive',
        'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
}

# %%
search = "vision pro"
url = f"https://news.google.com/search?q={search}&hl=en-US&gl=US&ceid=US%3Aen"

# %%
url_obj = session.get(url, headers = headers)
bs = BeautifulSoup(url_obj.text, 'html.parser')

# %%
def generatePrompt_summary(text):
    prompt = f'''
    your task is to generate a brief summary of the recent news of the recent website text, delimited with triple backticks.

    ```
    {text}
    ```
    '''
    return prompt

def generatePrompt_date(text):
    prompt = f'''
    your task is to find the published date of the following website text, delimited with triple backticks.
    you should retuen date in this format "mm/dd/yyyy".
    you should only response the date without any other text.

    ```
    {text}
    ```
    '''
    return prompt

# %%
load_dotenv()
openai.api_key = os.getenv("API_KEY")

def gpt(text):
    reply = openai.ChatCompletion.create(
                model = "gpt-3.5-turbo",
                messages = [
                    {"role": "user", "content": text}
                ]
            )
    return reply["choices"][0]["message"]["content"]

# %%
news = []
count = 0
for i in bs.find_all('a', class_ = "VDXfz"):
    this_news = {}
    url = "https://news.google.com/" + i['href'] # url at google
    url_obj = session.get(url, headers = headers)
    bs = BeautifulSoup(url_obj.text, "html.parser")
    url = bs.find('a', href=True, rel="nofollow")["href"] # real news url
    url_obj = session.get(url, headers = headers)
    bs = BeautifulSoup(url_obj.text, "html.parser")
    prompt_summary = generatePrompt_summary(bs.text)
    prompt_date = generatePrompt_date(bs.text)
    this_news['url'] = url
    this_news['summary'] = gpt(prompt_summary)
    this_news['date'] = gpt(prompt_date)
    news.append(this_news)
    print(len(news), news)
    if len(news) > 4:
        break
# Out:
# 1 [{'url': 'https://arstechnica.com/gadgets/2023/06/five-ways-vision-pro-is-different-from-anything-apple-or-anyone-has-ever-made/', 'summary': 'Apple has launched its Vision Pro headset at a starting price of $3,499. It is an augmented reality device that projects images on top of your natural view of the "real world" and has a number of use cases beyond those of existing virtual reality devices. According to analysts, the device’s product focus and software suggest “how different this AR headset could be from previous VR headsets—if Apple can get it right”.', 'date': '06/05/2023'}]
# 2 [{'url': 'https://arstechnica.com/gadgets/2023/06/five-ways-vision-pro-is-different-from-anything-apple-or-anyone-has-ever-made/', 'summary': 'Apple has launched its Vision Pro headset at a starting price of $3,499. It is an augmented reality device that projects images on top of your natural view of the "real world" and has a number of use cases beyond those of existing virtual reality devices. According to analysts, the device’s product focus and software suggest “how different this AR headset could be from previous VR headsets—if Apple can get it right”.', 'date': '06/05/2023'}, {'url': 'https://variety.com/2023/digital/news/apple-vr-headset-pricing-ship-date-specs-wwdc-1235632912/', 'summary': 'At the annual Worldwide Developers Conference (WWDC), Apple introduced its new Vision Pro headset, designed to offer VR and augmented reality (AR). The device features an "eyeSight" function that shows other people a wearer\'s eyes if they\'re in AR mode to "help users stay connected with those around them". The VR headset reportedly features 12 cameras, five sensors and six microphones. It also boasts apple\'s first 3D camera for capturing spatial video and photos. Additionally, Apple\'s own 3D games will be available on the headset, as well as hundreds of thousands of existing iPhone and iPad apps, with Unity developers able to create 3D apps for the platform too.', 'date': '06/05/2023'}]
# 3 [{'url': 'https://arstechnica.com/gadgets/2023/06/five-ways-vision-pro-is-different-from-anything-apple-or-anyone-has-ever-made/', 'summary': 'Apple has launched its Vision Pro headset at a starting price of $3,499. It is an augmented reality device that projects images on top of your natural view of the "real world" and has a number of use cases beyond those of existing virtual reality devices. According to analysts, the device’s product focus and software suggest “how different this AR headset could be from previous VR headsets—if Apple can get it right”.', 'date': '06/05/2023'}, {'url': 'https://variety.com/2023/digital/news/apple-vr-headset-pricing-ship-date-specs-wwdc-1235632912/', 'summary': 'At the annual Worldwide Developers Conference (WWDC), Apple introduced its new Vision Pro headset, designed to offer VR and augmented reality (AR). The device features an "eyeSight" function that shows other people a wearer\'s eyes if they\'re in AR mode to "help users stay connected with those around them". The VR headset reportedly features 12 cameras, five sensors and six microphones. It also boasts apple\'s first 3D camera for capturing spatial video and photos. Additionally, Apple\'s own 3D games will be available on the headset, as well as hundreds of thousands of existing iPhone and iPad apps, with Unity developers able to create 3D apps for the platform too.', 'date': '06/05/2023'}, {'url': 'https://www.theverge.com/2023/6/6/23751414/apple-tv-vision-pro-headset', 'summary': "Apple has unveiled its first-ever TV product in the form of the Vision Pro headset. While touted by Apple for its versatility, such as its potential for use in the production of immersive home movies and adding supplementary office and living room screens, Apple correspondent David Pierce believes that most immediate consumer interest will lie in its capabilities as a portable TV. Despite its retail price of $3,499, its ratings already\xa0high, with\xa0its wider field of view, 4K screen, and low-latency eye tracking all providing a high-quality viewing experience that surpasses similar options on the market. However, the device's relatively short battery life and lack of convenience is expected to limit its appeal when compared to traditional TV sets.", 'date': '06/06/2023'}]
# 4 [{'url': 'https://arstechnica.com/gadgets/2023/06/five-ways-vision-pro-is-different-from-anything-apple-or-anyone-has-ever-made/', 'summary': 'Apple has launched its Vision Pro headset at a starting price of $3,499. It is an augmented reality device that projects images on top of your natural view of the "real world" and has a number of use cases beyond those of existing virtual reality devices. According to analysts, the device’s product focus and software suggest “how different this AR headset could be from previous VR headsets—if Apple can get it right”.', 'date': '06/05/2023'}, {'url': 'https://variety.com/2023/digital/news/apple-vr-headset-pricing-ship-date-specs-wwdc-1235632912/', 'summary': 'At the annual Worldwide Developers Conference (WWDC), Apple introduced its new Vision Pro headset, designed to offer VR and augmented reality (AR). The device features an "eyeSight" function that shows other people a wearer\'s eyes if they\'re in AR mode to "help users stay connected with those around them". The VR headset reportedly features 12 cameras, five sensors and six microphones. It also boasts apple\'s first 3D camera for capturing spatial video and photos. Additionally, Apple\'s own 3D games will be available on the headset, as well as hundreds of thousands of existing iPhone and iPad apps, with Unity developers able to create 3D apps for the platform too.', 'date': '06/05/2023'}, {'url': 'https://www.theverge.com/2023/6/6/23751414/apple-tv-vision-pro-headset', 'summary': "Apple has unveiled its first-ever TV product in the form of the Vision Pro headset. While touted by Apple for its versatility, such as its potential for use in the production of immersive home movies and adding supplementary office and living room screens, Apple correspondent David Pierce believes that most immediate consumer interest will lie in its capabilities as a portable TV. Despite its retail price of $3,499, its ratings already\xa0high, with\xa0its wider field of view, 4K screen, and low-latency eye tracking all providing a high-quality viewing experience that surpasses similar options on the market. However, the device's relatively short battery life and lack of convenience is expected to limit its appeal when compared to traditional TV sets.", 'date': '06/06/2023'}, {'url': 'https://www.cnbc.com/2023/06/06/apple-vision-pro-hands-on-first-impressions-from-wwdc-2023.html', 'summary': 'Apple has unveiled its new mixed-reality headset called the Vision Pro, which it demonstrated at its annual Worldwide Developers Conference. The headset features sharp displays, snap-in prescription lenses and also allows users to place a virtual movie screen anywhere in the room. An array of apps including Apple TV, Safari and photographs can be manipulated in 3D space and users can train the internal cameras to track eyes. The price of the device has attracted criticism due to its cost of $3,500. However, industry commentators have noted its superior clarity of display compared to competitors.', 'date': '06/06/2023'}]
# 5 [{'url': 'https://arstechnica.com/gadgets/2023/06/five-ways-vision-pro-is-different-from-anything-apple-or-anyone-has-ever-made/', 'summary': 'Apple has launched its Vision Pro headset at a starting price of $3,499. It is an augmented reality device that projects images on top of your natural view of the "real world" and has a number of use cases beyond those of existing virtual reality devices. According to analysts, the device’s product focus and software suggest “how different this AR headset could be from previous VR headsets—if Apple can get it right”.', 'date': '06/05/2023'}, {'url': 'https://variety.com/2023/digital/news/apple-vr-headset-pricing-ship-date-specs-wwdc-1235632912/', 'summary': 'At the annual Worldwide Developers Conference (WWDC), Apple introduced its new Vision Pro headset, designed to offer VR and augmented reality (AR). The device features an "eyeSight" function that shows other people a wearer\'s eyes if they\'re in AR mode to "help users stay connected with those around them". The VR headset reportedly features 12 cameras, five sensors and six microphones. It also boasts apple\'s first 3D camera for capturing spatial video and photos. Additionally, Apple\'s own 3D games will be available on the headset, as well as hundreds of thousands of existing iPhone and iPad apps, with Unity developers able to create 3D apps for the platform too.', 'date': '06/05/2023'}, {'url': 'https://www.theverge.com/2023/6/6/23751414/apple-tv-vision-pro-headset', 'summary': "Apple has unveiled its first-ever TV product in the form of the Vision Pro headset. While touted by Apple for its versatility, such as its potential for use in the production of immersive home movies and adding supplementary office and living room screens, Apple correspondent David Pierce believes that most immediate consumer interest will lie in its capabilities as a portable TV. Despite its retail price of $3,499, its ratings already\xa0high, with\xa0its wider field of view, 4K screen, and low-latency eye tracking all providing a high-quality viewing experience that surpasses similar options on the market. However, the device's relatively short battery life and lack of convenience is expected to limit its appeal when compared to traditional TV sets.", 'date': '06/06/2023'}, {'url': 'https://www.cnbc.com/2023/06/06/apple-vision-pro-hands-on-first-impressions-from-wwdc-2023.html', 'summary': 'Apple has unveiled its new mixed-reality headset called the Vision Pro, which it demonstrated at its annual Worldwide Developers Conference. The headset features sharp displays, snap-in prescription lenses and also allows users to place a virtual movie screen anywhere in the room. An array of apps including Apple TV, Safari and photographs can be manipulated in 3D space and users can train the internal cameras to track eyes. The price of the device has attracted criticism due to its cost of $3,500. However, industry commentators have noted its superior clarity of display compared to competitors.', 'date': '06/06/2023'}, {'url': 'https://www.nytimes.com/2023/06/06/technology/personaltech/apple-vision-pro-headset-try.html', 'summary': 'Apple has unveiled its $3,500 Vision Pro headset, which is set to be released next year. Brian X. Chen from The New York Times was given a pre-production model to test, which he said "impressed and creeped me out", with some concerns that the product lacked the social connection element needed for it to resonate with consumers. The headset features high-resolution video, intuitive controls and a comfortable fit. However, Chen noted there was nothing new and questioned why anyone would need the product.', 'date': '06/06/2023'}]

# %%
news
# Out:
# [{'url': 'https://arstechnica.com/gadgets/2023/06/five-ways-vision-pro-is-different-from-anything-apple-or-anyone-has-ever-made/',
#   'summary': 'Apple has launched its Vision Pro headset at a starting price of $3,499. It is an augmented reality device that projects images on top of your natural view of the "real world" and has a number of use cases beyond those of existing virtual reality devices. According to analysts, the device’s product focus and software suggest “how different this AR headset could be from previous VR headsets—if Apple can get it right”.',
#   'date': '06/05/2023'},
#  {'url': 'https://variety.com/2023/digital/news/apple-vr-headset-pricing-ship-date-specs-wwdc-1235632912/',
#   'summary': 'At the annual Worldwide Developers Conference (WWDC), Apple introduced its new Vision Pro headset, designed to offer VR and augmented reality (AR). The device features an "eyeSight" function that shows other people a wearer\'s eyes if they\'re in AR mode to "help users stay connected with those around them". The VR headset reportedly features 12 cameras, five sensors and six microphones. It also boasts apple\'s first 3D camera for capturing spatial video and photos. Additionally, Apple\'s own 3D games will be available on the headset, as well as hundreds of thousands of existing iPhone and iPad apps, with Unity developers able to create 3D apps for the platform too.',
#   'date': '06/05/2023'},
#  {'url': 'https://www.theverge.com/2023/6/6/23751414/apple-tv-vision-pro-headset',
#   'summary': "Apple has unveiled its first-ever TV product in the form of the Vision Pro headset. While touted by Apple for its versatility, such as its potential for use in the production of immersive home movies and adding supplementary office and living room screens, Apple correspondent David Pierce believes that most immediate consumer interest will lie in its capabilities as a portable TV. Despite its retail price of $3,499, its ratings already\xa0high, with\xa0its wider field of view, 4K screen, and low-latency eye tracking all providing a high-quality viewing experience that surpasses similar options on the market. However, the device's relatively short battery life and lack of convenience is expected to limit its appeal when compared to traditional TV sets.",
#   'date': '06/06/2023'},
#  {'url': 'https://www.cnbc.com/2023/06/06/apple-vision-pro-hands-on-first-impressions-from-wwdc-2023.html',
#   'summary': 'Apple has unveiled its new mixed-reality headset called the Vision Pro, which it demonstrated at its annual Worldwide Developers Conference. The headset features sharp displays, snap-in prescription lenses and also allows users to place a virtual movie screen anywhere in the room. An array of apps including Apple TV, Safari and photographs can be manipulated in 3D space and users can train the internal cameras to track eyes. The price of the device has attracted criticism due to its cost of $3,500. However, industry commentators have noted its superior clarity of display compared to competitors.',
#   'date': '06/06/2023'},
#  {'url': 'https://www.nytimes.com/2023/06/06/technology/personaltech/apple-vision-pro-headset-try.html',
#   'summary': 'Apple has unveiled its $3,500 Vision Pro headset, which is set to be released next year. Brian X. Chen from The New York Times was given a pre-production model to test, which he said "impressed and creeped me out", with some concerns that the product lacked the social connection element needed for it to resonate with consumers. The headset features high-resolution video, intuitive controls and a comfortable fit. However, Chen noted there was nothing new and questioned why anyone would need the product.',
#   'date': '06/06/2023'}]

# %% [markdown]
# # Another Way

# %%
import openai
import requests
import os
from googleapiclient.discovery import build
from datetime import datetime, timedelta

# %%
def openFile(path):
    with open(path, 'r', encoding="utf-8") as infile:
        return infile.read()
    
def saveFile(path, content):
    with open(path, 'w', encoding='utf-8') as outfile:
        outfile.write(content)

api_key = "AIzaSyDPIx9OJrQzzi95wj5cuFMc8GvvI8bxpJI"
api_cx = "017576662512468239146:omuauf_lfve"
